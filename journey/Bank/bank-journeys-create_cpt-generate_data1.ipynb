# %%
#to export a notebook to html use:
# >ipython nbconvert --to html Process-GitHub-Repos.ipynb

from pandas import DataFrame, Series
import pandas as pd
import matplotlib.pyplot as plt
import string
from datetime import datetime, date, time

import re
# %pylab inline
import numpy as np
import scipy as sc
import scipy.stats as stats
from scipy.optimize import leastsq
from graphviz import Digraph
import operator
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# #CREATE CPTs

# %%
from collections import Counter

data_file = './datasets/journeys.csv'
file = open(data_file, 'r')
df_f = DataFrame.from_csv(data_file)
df = df_f.loc[:,('trans_id','topic_intent_eng','channel','action_eng','cluster')]
df['journey_id'] = df.index

# %%
df['channel_gen'] = map(lambda c: 'live' if c in ['f2f','phone'] else 'self', df['channel'] )
df['cluster'] = map(lambda c: 'young' if c==1 else 'old', df['cluster'] )
df
# Out:
# <div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>trans_id</th>
#       <th>topic_intent_eng</th>
#       <th>channel</th>
#       <th>action_eng</th>
#       <th>cluster</th>
#       <th>journey_id</th>
#       <th>channel_gen</th>
#     </tr>
#     <tr>
#       <th>jorney_id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1 </th>
#       <td> 1</td>
#       <td>   purchase foreign currency</td>
#       <td>   web</td>
#       <td>          purchase</td>
#       <td> young</td>
#       <td>  1</td>
#       <td> self</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td> 1</td>
#       <td>   purchase foreign currency</td>
#       <td>   f2f</td>
#       <td>          purchase</td>
#       <td>   old</td>
#       <td>  2</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td> 1</td>
#       <td>   purchase foreign currency</td>
#       <td> phone</td>
#       <td>          purchase</td>
#       <td> young</td>
#       <td>  3</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td> 1</td>
#       <td>           order credit card</td>
#       <td> phone</td>
#       <td>           request</td>
#       <td>   old</td>
#       <td>  4</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td> 2</td>
#       <td>           order credit card</td>
#       <td>   f2f</td>
#       <td> collect at branch</td>
#       <td>   old</td>
#       <td>  4</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td> 1</td>
#       <td>           order credit card</td>
#       <td> phone</td>
#       <td>          proposal</td>
#       <td> young</td>
#       <td>  5</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td> 2</td>
#       <td>           order credit card</td>
#       <td> phone</td>
#       <td>           request</td>
#       <td> young</td>
#       <td>  5</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td> 3</td>
#       <td>           order credit card</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td> young</td>
#       <td>  5</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td> 4</td>
#       <td>           order credit card</td>
#       <td>   f2f</td>
#       <td> collect at branch</td>
#       <td> young</td>
#       <td>  5</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td> 1</td>
#       <td>                order checks</td>
#       <td>   web</td>
#       <td>           request</td>
#       <td> young</td>
#       <td>  6</td>
#       <td> self</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td> 2</td>
#       <td>                order checks</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td> young</td>
#       <td>  6</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td> 3</td>
#       <td>                order checks</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td> young</td>
#       <td>  6</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td> 4</td>
#       <td>                order checks</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td> young</td>
#       <td>  6</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td> 5</td>
#       <td>                order checks</td>
#       <td>   f2f</td>
#       <td> collect at branch</td>
#       <td> young</td>
#       <td>  6</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td> 1</td>
#       <td>                order checks</td>
#       <td>   f2f</td>
#       <td>           request</td>
#       <td>   old</td>
#       <td>  7</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td> 2</td>
#       <td>                order checks</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td>   old</td>
#       <td>  7</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td> 3</td>
#       <td>                order checks</td>
#       <td>   f2f</td>
#       <td> collect at branch</td>
#       <td>   old</td>
#       <td>  7</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td> 1</td>
#       <td>            issue bank check</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td>   old</td>
#       <td>  8</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td> 2</td>
#       <td>            issue bank check</td>
#       <td>   f2f</td>
#       <td> collect at branch</td>
#       <td>   old</td>
#       <td>  8</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td> 1</td>
#       <td>            issue bank check</td>
#       <td>   f2f</td>
#       <td> collect at branch</td>
#       <td> young</td>
#       <td>  9</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td> 1</td>
#       <td>               check balance</td>
#       <td>   web</td>
#       <td>           inquiry</td>
#       <td>   old</td>
#       <td> 10</td>
#       <td> self</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td> 1</td>
#       <td>               check balance</td>
#       <td>   ivr</td>
#       <td>           inquiry</td>
#       <td>   old</td>
#       <td> 11</td>
#       <td> self</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td> 1</td>
#       <td>              change address</td>
#       <td>   web</td>
#       <td>    change details</td>
#       <td> young</td>
#       <td> 12</td>
#       <td> self</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td> 1</td>
#       <td>              change address</td>
#       <td> phone</td>
#       <td>    change details</td>
#       <td>   old</td>
#       <td> 13</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td> 1</td>
#       <td>              change address</td>
#       <td>   f2f</td>
#       <td>    change details</td>
#       <td>   old</td>
#       <td> 14</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td> 1</td>
#       <td>            check commission</td>
#       <td>   web</td>
#       <td>           inquiry</td>
#       <td> young</td>
#       <td> 15</td>
#       <td> self</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td> 2</td>
#       <td>            check commission</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td> young</td>
#       <td> 15</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td> 3</td>
#       <td>            check commission</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td> young</td>
#       <td> 15</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td> 1</td>
#       <td>            check commission</td>
#       <td>   ivr</td>
#       <td>           inquiry</td>
#       <td>   old</td>
#       <td> 16</td>
#       <td> self</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td> 2</td>
#       <td>            check commission</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td>   old</td>
#       <td> 16</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td> 3</td>
#       <td>            check commission</td>
#       <td> phone</td>
#       <td>           inquiry</td>
#       <td>   old</td>
#       <td> 16</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td> 4</td>
#       <td>            check commission</td>
#       <td>   f2f</td>
#       <td>           inquiry</td>
#       <td>   old</td>
#       <td> 16</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td> 1</td>
#       <td>               withdraw cash</td>
#       <td>   f2f</td>
#       <td>        withdrawal</td>
#       <td>   old</td>
#       <td> 17</td>
#       <td> live</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td> 1</td>
#       <td>               withdraw cash</td>
#       <td>   ivr</td>
#       <td>        withdrawal</td>
#       <td> young</td>
#       <td> 18</td>
#       <td> self</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td> 1</td>
#       <td>                wiretransfer</td>

# %% [markdown]
# ###CREATE CLUSTER-ACTION-ACTION CPT

# %%
df1 = df.loc[:,('trans_id','topic_intent_eng','channel','action_eng','cluster')].reset_index()
df2 = df1.copy()

df1 = df1.rename(columns={'action_eng':'from_action'})
df2 = df2.rename(columns={'action_eng':'to_action'})

df2['trans_id'] = df2['trans_id'] - 1
# df1.loc[df1.trans_id == 1, 'from_action'] = 'start'

# %%
df_trans = pd.merge(df1, df2, how='outer', on=['jorney_id','trans_id'], sort=['jorney_id','trans_id'])

df_trans.from_action.fillna('start', inplace=True)
df_trans.to_action.fillna('end', inplace=True)

df_trans.fillna('',inplace=True)
df_trans['cluster'] = np.where(df_trans.cluster_x == '', df_trans.cluster_y, df_trans.cluster_x)

df_trans = df_trans.loc[:,('jorney_id','trans_id', 'cluster' ,'from_action','to_action')]

# %%
#CREATE ACTION-ACTION counts from data
df_action_action_count = DataFrame(df_trans.groupby(['cluster','from_action','to_action']).count().loc[:,('trans_id')]).rename(columns={'trans_id':'count'})

# %%
# CREATE ACTION-ACTION SMOOTHING TABLE
distinct_actions = df.action_eng.unique().tolist()+['start', 'end']
# distinct_actions = df.action_eng.unique().tolist()+['start']
clusters = df_trans.cluster.unique()
from_to_actions = []
for c in clusters:
    for f in distinct_actions:
        for t in distinct_actions:
            count = 1
            if(f==t=='end'):
                count = 100000
            from_to_actions.append((c,f,t,count))
        
df_action_action_smoothing = DataFrame(from_to_actions, columns=['cluster','from_action', 'to_action', 'count'])
from_to_actions
# Out:
# [('young', 'purchase', 'purchase', 1),
#  ('young', 'purchase', 'request', 1),
#  ('young', 'purchase', 'collect at branch', 1),
#  ('young', 'purchase', 'proposal', 1),
#  ('young', 'purchase', 'inquiry', 1),
#  ('young', 'purchase', 'change details', 1),
#  ('young', 'purchase', 'withdrawal', 1),
#  ('young', 'purchase', 'response', 1),
#  ('young', 'purchase', 'talk with manager', 1),
#  ('young', 'purchase', 'message', 1),
#  ('young', 'purchase', 'notification', 1),
#  ('young', 'purchase', 'sign documents', 1),
#  ('young', 'purchase', 'start', 1),
#  ('young', 'purchase', 'end', 1),
#  ('young', 'request', 'purchase', 1),
#  ('young', 'request', 'request', 1),
#  ('young', 'request', 'collect at branch', 1),
#  ('young', 'request', 'proposal', 1),
#  ('young', 'request', 'inquiry', 1),
#  ('young', 'request', 'change details', 1),
#  ('young', 'request', 'withdrawal', 1),
#  ('young', 'request', 'response', 1),
#  ('young', 'request', 'talk with manager', 1),
#  ('young', 'request', 'message', 1),
#  ('young', 'request', 'notification', 1),
#  ('young', 'request', 'sign documents', 1),
#  ('young', 'request', 'start', 1),
#  ('young', 'request', 'end', 1),
#  ('young', 'collect at branch', 'purchase', 1),
#  ('young', 'collect at branch', 'request', 1),
#  ('young', 'collect at branch', 'collect at branch', 1),
#  ('young', 'collect at branch', 'proposal', 1),
#  ('young', 'collect at branch', 'inquiry', 1),
#  ('young', 'collect at branch', 'change details', 1),
#  ('young', 'collect at branch', 'withdrawal', 1),
#  ('young', 'collect at branch', 'response', 1),
#  ('young', 'collect at branch', 'talk with manager', 1),
#  ('young', 'collect at branch', 'message', 1),
#  ('young', 'collect at branch', 'notification', 1),
#  ('young', 'collect at branch', 'sign documents', 1),
#  ('young', 'collect at branch', 'start', 1),
#  ('young', 'collect at branch', 'end', 1),
#  ('young', 'proposal', 'purchase', 1),
#  ('young', 'proposal', 'request', 1),
#  ('young', 'proposal', 'collect at branch', 1),
#  ('young', 'proposal', 'proposal', 1),
#  ('young', 'proposal', 'inquiry', 1),
#  ('young', 'proposal', 'change details', 1),
#  ('young', 'proposal', 'withdrawal', 1),
#  ('young', 'proposal', 'response', 1),
#  ('young', 'proposal', 'talk with manager', 1),
#  ('young', 'proposal', 'message', 1),
#  ('young', 'proposal', 'notification', 1),
#  ('young', 'proposal', 'sign documents', 1),
#  ('young', 'proposal', 'start', 1),
#  ('young', 'proposal', 'end', 1),
#  ('young', 'inquiry', 'purchase', 1),
#  ('young', 'inquiry', 'request', 1),
#  ('young', 'inquiry', 'collect at branch', 1),
#  ('young', 'inquiry', 'proposal', 1),
#  ('young', 'inquiry', 'inquiry', 1),
#  ('young', 'inquiry', 'change details', 1),
#  ('young', 'inquiry', 'withdrawal', 1),
#  ('young', 'inquiry', 'response', 1),
#  ('young', 'inquiry', 'talk with manager', 1),
#  ('young', 'inquiry', 'message', 1),
#  ('young', 'inquiry', 'notification', 1),
#  ('young', 'inquiry', 'sign documents', 1),
#  ('young', 'inquiry', 'start', 1),
#  ('young', 'inquiry', 'end', 1),
#  ('young', 'change details', 'purchase', 1),
#  ('young', 'change details', 'request', 1),
#  ('young', 'change details', 'collect at branch', 1),
#  ('young', 'change details', 'proposal', 1),
#  ('young', 'change details', 'inquiry', 1),
#  ('young', 'change details', 'change details', 1),
#  ('young', 'change details', 'withdrawal', 1),
#  ('young', 'change details', 'response', 1),
#  ('young', 'change details', 'talk with manager', 1),
#  ('young', 'change details', 'message', 1),
#  ('young', 'change details', 'notification', 1),
#  ('young', 'change details', 'sign documents', 1),
#  ('young', 'change details', 'start', 1),
#  ('young', 'change details', 'end', 1),
#  ('young', 'withdrawal', 'purchase', 1),
#  ('young', 'withdrawal', 'request', 1),
#  ('young', 'withdrawal', 'collect at branch', 1),
#  ('young', 'withdrawal', 'proposal', 1),
#  ('young', 'withdrawal', 'inquiry', 1),
#  ('young', 'withdrawal', 'change details', 1),
#  ('young', 'withdrawal', 'withdrawal', 1),
#  ('young', 'withdrawal', 'response', 1),
#  ('young', 'withdrawal', 'talk with manager', 1),
#  ('young', 'withdrawal', 'message', 1),
#  ('young', 'withdrawal', 'notification', 1),
#  ('young', 'withdrawal', 'sign documents', 1),
#  ('young', 'withdrawal', 'start', 1),
#  ('young', 'withdrawal', 'end', 1),
#  ('young', 'response', 'purchase', 1),
#  ('young', 'response', 'request', 1),
#  ('young', 'response', 'collect at branch', 1),
#  ('young', 'response', 'proposal', 1),
#  ('young', 'response', 'inquiry', 1),
#  ('young', 'response', 'change details', 1),
#  ('young', 'response', 'withdrawal', 1),
#  ('young', 'response', 'response', 1),
#  ('young', 'response', 'talk with manager', 1),
#  ('young', 'response', 'message', 1),
#  ('young', 'response', 'notification', 1),
#  ('young', 'response', 'sign documents', 1),
#  ('young', 'response', 'start', 1),
#  ('young', 'response', 'end', 1),
#  ('young', 'talk with manager', 'purchase', 1),
#  ('young', 'talk with manager', 'request', 1),
#  ('young', 'talk with manager', 'collect at branch', 1),
#  ('young', 'talk with manager', 'proposal', 1),
#  ('young', 'talk with manager', 'inquiry', 1),
#  ('young', 'talk with manager', 'change details', 1),
#  ('young', 'talk with manager', 'withdrawal', 1),
#  ('young', 'talk with manager', 'response', 1),
#  ('young', 'talk with manager', 'talk with manager', 1),
#  ('young', 'talk with manager', 'message', 1),
#  ('young', 'talk with manager', 'notification', 1),
#  ('young', 'talk with manager', 'sign documents', 1),
#  ('young', 'talk with manager', 'start', 1),
#  ('young', 'talk with manager', 'end', 1),
#  ('young', 'message', 'purchase', 1),
#  ('young', 'message', 'request', 1),
#  ('young', 'message', 'collect at branch', 1),
#  ('young', 'message', 'proposal', 1),
#  ('young', 'message', 'inquiry', 1),
#  ('young', 'message', 'change details', 1),
#  ('young', 'message', 'withdrawal', 1),
#  ('young', 'message', 'response', 1),
#  ('young', 'message', 'talk with manager', 1),
#  ('young', 'message', 'message', 1),
#  ('young', 'message', 'notification', 1),
#  ('young', 'message', 'sign documents', 1),
#  ('young', 'message', 'start', 1),
#  ('young', 'message', 'end', 1),
#  ('young', 'notification', 'purchase', 1),
#  ('young', 'notification', 'request', 1),
#  ('young', 'notification', 'collect at branch', 1),
#  ('young', 'notification', 'proposal', 1),
#  ('young', 'notification', 'inquiry', 1),
#  ('young', 'notification', 'change details', 1),
#  ('young', 'notification', 'withdrawal', 1),
#  ('young', 'notification', 'response', 1),
#  ('young', 'notification', 'talk with manager', 1),
#  ('young', 'notification', 'message', 1),
#  ('young', 'notification', 'notification', 1),
#  ('young', 'notification', 'sign documents', 1),
#  ('young', 'notification', 'start', 1),
#  ('young', 'notification', 'end', 1),
#  ('young', 'sign documents', 'purchase', 1),
#  ('young', 'sign documents', 'request', 1),
#  ('young', 'sign documents', 'collect at branch', 1),
#  ('young', 'sign documents', 'proposal', 1),
#  ('young', 'sign documents', 'inquiry', 1),
#  ('young', 'sign documents', 'change details', 1),
#  ('young', 'sign documents', 'withdrawal', 1),
#  ('young', 'sign documents', 'response', 1),
#  ('young', 'sign documents', 'talk with manager', 1),
#  ('young', 'sign documents', 'message', 1),
#  ('young', 'sign documents', 'notification', 1),
#  ('young', 'sign documents', 'sign documents', 1),
#  ('young', 'sign documents', 'start', 1),
#  ('young', 'sign documents', 'end', 1),
#  ('young', 'start', 'purchase', 1),
#  ('young', 'start', 'request', 1),
#  ('young', 'start', 'collect at branch', 1),
#  ('young', 'start', 'proposal', 1),
#  ('young', 'start', 'inquiry', 1),
#  ('young', 'start', 'change details', 1),
#  ('young', 'start', 'withdrawal', 1),
#  ('young', 'start', 'response', 1),
#  ('young', 'start', 'talk with manager', 1),
#  ('young', 'start', 'message', 1),
#  ('young', 'start', 'notification', 1),
#  ('young', 'start', 'sign documents', 1),
#  ('young', 'start', 'start', 1),
#  ('young', 'start', 'end', 1),
#  ('young', 'end', 'purchase', 1),
#  ('young', 'end', 'request', 1),
#  ('young', 'end', 'collect at branch', 1),
#  ('young', 'end', 'proposal', 1),
#  ('young', 'end', 'inquiry', 1),
#  ('young', 'end', 'change details', 1),
#  ('young', 'end', 'withdrawal', 1),
#  ('young', 'end', 'response', 1),
#  ('young', 'end', 'talk with manager', 1),
#  ('young', 'end', 'message', 1),
#  ('young', 'end', 'notification', 1),
#  ('young', 'end', 'sign documents', 1),
#  ('young', 'end', 'start', 1),
#  ('young', 'end', 'end', 100000),
#  ('old', 'purchase', 'purchase', 1),
#  ('old', 'purchase', 'request', 1),
#  ('old', 'purchase', 'collect at branch', 1),
#  ('old', 'purchase', 'proposal', 1),
#  ('old', 'purchase', 'inquiry', 1),
#  ('old', 'purchase', 'change details', 1),
#  ('old', 'purchase', 'withdrawal', 1),
#  ('old', 'purchase', 'response', 1),
#  ('old', 'purchase', 'talk with manager', 1),
#  ('old', 'purchase', 'message', 1),
#  ('old', 'purchase', 'notification', 1),
#  ('old', 'purchase', 'sign documents', 1),
#  ('old', 'purchase', 'start', 1),
#  ('old', 'purchase', 'end', 1),
#  ('old', 'request', 'purchase', 1),
#  ('old', 'request', 'request', 1),
#  ('old', 'request', 'collect at branch', 1),
#  ('old', 'request', 'proposal', 1),
#  ('old', 'request', 'inquiry', 1),
#  ('old', 'request', 'change details', 1),
#  ('old', 'request', 'withdrawal', 1),
#  ('old', 'request', 'response', 1),
#  ('old', 'request', 'talk with manager', 1),
#  ('old', 'request', 'message', 1),
#  ('old', 'request', 'notification', 1),
#  ('old', 'request', 'sign documents', 1),
#  ('old', 'request', 'start', 1),
#  ('old', 'request', 'end', 1),
#  ('old', 'collect at branch', 'purchase', 1),
#  ('old', 'collect at branch', 'request', 1),
#  ('old', 'collect at branch', 'collect at branch', 1),
#  ('old', 'collect at branch', 'proposal', 1),
#  ('old', 'collect at branch', 'inquiry', 1),
#  ('old', 'collect at branch', 'change details', 1),
#  ('old', 'collect at branch', 'withdrawal', 1),
#  ('old', 'collect at branch', 'response', 1),
#  ('old', 'collect at branch', 'talk with manager', 1),
#  ('old', 'collect at branch', 'message', 1),
#  ('old', 'collect at branch', 'notification', 1),
#  ('old', 'collect at branch', 'sign documents', 1),
#  ('old', 'collect at branch', 'start', 1),
#  ('old', 'collect at branch', 'end', 1),
#  ('old', 'proposal', 'purchase', 1),
#  ('old', 'proposal', 'request', 1),
#  ('old', 'proposal', 'collect at branch', 1),
#  ('old', 'proposal', 'proposal', 1),
#  ('old', 'proposal', 'inquiry', 1),
#  ('old', 'proposal', 'change details', 1),
#  ('old', 'proposal', 'withdrawal', 1),
#  ('old', 'proposal', 'response', 1),
#  ('old', 'proposal', 'talk with manager', 1),
#  ('old', 'proposal', 'message', 1),
#  ('old', 'proposal', 'notification', 1),
#  ('old', 'proposal', 'sign documents', 1),
#  ('old', 'proposal', 'start', 1),
#  ('old', 'proposal', 'end', 1),
#  ('old', 'inquiry', 'purchase', 1),
#  ('old', 'inquiry', 'request', 1),
#  ('old', 'inquiry', 'collect at branch', 1),
#  ('old', 'inquiry', 'proposal', 1),
#  ('old', 'inquiry', 'inquiry', 1),
#  ('old', 'inquiry', 'change details', 1),
#  ('old', 'inquiry', 'withdrawal', 1),
#  ('old', 'inquiry', 'response', 1),
#  ('old', 'inquiry', 'talk with manager', 1),
#  ('old', 'inquiry', 'message', 1),
#  ('old', 'inquiry', 'notification', 1),
#  ('old', 'inquiry', 'sign documents', 1),
#  ('old', 'inquiry', 'start', 1),
#  ('old', 'inquiry', 'end', 1),
#  ('old', 'change details', 'purchase', 1),
#  ('old', 'change details', 'request', 1),
#  ('old', 'change details', 'collect at branch', 1),
#  ('old', 'change details', 'proposal', 1),
#  ('old', 'change details', 'inquiry', 1),
#  ('old', 'change details', 'change details', 1),
#  ('old', 'change details', 'withdrawal', 1),
#  ('old', 'change details', 'response', 1),
#  ('old', 'change details', 'talk with manager', 1),
#  ('old', 'change details', 'message', 1),
#  ('old', 'change details', 'notification', 1),
#  ('old', 'change details', 'sign documents', 1),
#  ('old', 'change details', 'start', 1),
#  ('old', 'change details', 'end', 1),
#  ('old', 'withdrawal', 'purchase', 1),
#  ('old', 'withdrawal', 'request', 1),
#  ('old', 'withdrawal', 'collect at branch', 1),
#  ('old', 'withdrawal', 'proposal', 1),
#  ('old', 'withdrawal', 'inquiry', 1),
#  ('old', 'withdrawal', 'change details', 1),
#  ('old', 'withdrawal', 'withdrawal', 1),
#  ('old', 'withdrawal', 'response', 1),
#  ('old', 'withdrawal', 'talk with manager', 1),
#  ('old', 'withdrawal', 'message', 1),
#  ('old', 'withdrawal', 'notification', 1),
#  ('old', 'withdrawal', 'sign documents', 1),
#  ('old', 'withdrawal', 'start', 1),
#  ('old', 'withdrawal', 'end', 1),
#  ('old', 'response', 'purchase', 1),
#  ('old', 'response', 'request', 1),
#  ('old', 'response', 'collect at branch', 1),
#  ('old', 'response', 'proposal', 1),
#  ('old', 'response', 'inquiry', 1),
#  ('old', 'response', 'change details', 1),
#  ('old', 'response', 'withdrawal', 1),
#  ('old', 'response', 'response', 1),
#  ('old', 'response', 'talk with manager', 1),
#  ('old', 'response', 'message', 1),
#  ('old', 'response', 'notification', 1),
#  ('old', 'response', 'sign documents', 1),
#  ('old', 'response', 'start', 1),
#  ('old', 'response', 'end', 1),
#  ('old', 'talk with manager', 'purchase', 1),
#  ('old', 'talk with manager', 'request', 1),
#  ('old', 'talk with manager', 'collect at branch', 1),
#  ('old', 'talk with manager', 'proposal', 1),
#  ('old', 'talk with manager', 'inquiry', 1),
#  ('old', 'talk with manager', 'change details', 1),
#  ('old', 'talk with manager', 'withdrawal', 1),
#  ('old', 'talk with manager', 'response', 1),
#  ('old', 'talk with manager', 'talk with manager', 1),
#  ('old', 'talk with manager', 'message', 1),
#  ('old', 'talk with manager', 'notification', 1),
#  ('old', 'talk with manager', 'sign documents', 1),
#  ('old', 'talk with manager', 'start', 1),
#  ('old', 'talk with manager', 'end', 1),
#  ('old', 'message', 'purchase', 1),
#  ('old', 'message', 'request', 1),
#  ('old', 'message', 'collect at branch', 1),
#  ('old', 'message', 'proposal', 1),
#  ('old', 'message', 'inquiry', 1),
#  ('old', 'message', 'change details', 1),
#  ('old', 'message', 'withdrawal', 1),
#  ('old', 'message', 'response', 1),
#  ('old', 'message', 'talk with manager', 1),
#  ('old', 'message', 'message', 1),
#  ('old', 'message', 'notification', 1),
#  ('old', 'message', 'sign documents', 1),
#  ('old', 'message', 'start', 1),
#  ('old', 'message', 'end', 1),
#  ('old', 'notification', 'purchase', 1),
#  ('old', 'notification', 'request', 1),
#  ('old', 'notification', 'collect at branch', 1),
#  ('old', 'notification', 'proposal', 1),
#  ('old', 'notification', 'inquiry', 1),
#  ('old', 'notification', 'change details', 1),
#  ('old', 'notification', 'withdrawal', 1),
#  ('old', 'notification', 'response', 1),
#  ('old', 'notification', 'talk with manager', 1),
#  ('old', 'notification', 'message', 1),
#  ('old', 'notification', 'notification', 1),
#  ('old', 'notification', 'sign documents', 1),
#  ('old', 'notification', 'start', 1),
#  ('old', 'notification', 'end', 1),
#  ('old', 'sign documents', 'purchase', 1),
#  ('old', 'sign documents', 'request', 1),
#  ('old', 'sign documents', 'collect at branch', 1),
#  ('old', 'sign documents', 'proposal', 1),
#  ('old', 'sign documents', 'inquiry', 1),
#  ('old', 'sign documents', 'change details', 1),
#  ('old', 'sign documents', 'withdrawal', 1),
#  ('old', 'sign documents', 'response', 1),
#  ('old', 'sign documents', 'talk with manager', 1),
#  ('old', 'sign documents', 'message', 1),
#  ('old', 'sign documents', 'notification', 1),
#  ('old', 'sign documents', 'sign documents', 1),
#  ('old', 'sign documents', 'start', 1),
#  ('old', 'sign documents', 'end', 1),
#  ('old', 'start', 'purchase', 1),
#  ('old', 'start', 'request', 1),
#  ('old', 'start', 'collect at branch', 1),
#  ('old', 'start', 'proposal', 1),
#  ('old', 'start', 'inquiry', 1),
#  ('old', 'start', 'change details', 1),
#  ('old', 'start', 'withdrawal', 1),
#  ('old', 'start', 'response', 1),
#  ('old', 'start', 'talk with manager', 1),
#  ('old', 'start', 'message', 1),
#  ('old', 'start', 'notification', 1),
#  ('old', 'start', 'sign documents', 1),
#  ('old', 'start', 'start', 1),
#  ('old', 'start', 'end', 1),
#  ('old', 'end', 'purchase', 1),
#  ('old', 'end', 'request', 1),
#  ('old', 'end', 'collect at branch', 1),
#  ('old', 'end', 'proposal', 1),
#  ('old', 'end', 'inquiry', 1),
#  ('old', 'end', 'change details', 1),
#  ('old', 'end', 'withdrawal', 1),
#  ('old', 'end', 'response', 1),
#  ('old', 'end', 'talk with manager', 1),
#  ('old', 'end', 'message', 1),
#  ('old', 'end', 'notification', 1),
#  ('old', 'end', 'sign documents', 1),
#  ('old', 'end', 'start', 1),
#  ('old', 'end', 'end', 100000)]

# %%
# CREATE ACTION-ACTION SMOOTHED
df_action_action_count_smothed = pd.merge(df_action_action_smoothing, df_action_action_count.reset_index(), how='left', on=['cluster', 'from_action', 'to_action'], suffixes=['','_y'])
df_action_action_count_smothed.count_y.fillna(0, inplace=True)
df_action_action_count_smothed['count'] = df_action_action_count_smothed['count'] + df_action_action_count_smothed['count_y']*100
df_action_action_count_smothed.drop('count_y', inplace=True, axis=1)
df_action_action_count_smothed = df_action_action_count_smothed[df_action_action_count_smothed.to_action != 'start']
# df_action_action_count_smothed = df_action_action_count_smothed[df_action_action_count_smothed.from_action != 'end']
df_action_action_count_smothed.reset_index(inplace=True)
df_action_action_count_smothed.drop('index', inplace=True, axis=1)
df_action_action_count_smothed = df_action_action_count_smothed.set_index(['cluster', 'from_action', 'to_action'])
df_action_action_count_smothed
# Out:
# <div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>cluster</th>
#       <th>from_action</th>
#       <th>to_action</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="30" valign="top">young</th>
#       <th rowspan="13" valign="top">purchase</th>
#       <th>purchase</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>inquiry</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>change details</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>withdrawal</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>response</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>talk with manager</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>message</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td>    201</td>
#     </tr>
#     <tr>
#       <th rowspan="13" valign="top">request</th>
#       <th>purchase</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>inquiry</th>
#       <td>    301</td>
#     </tr>
#     <tr>
#       <th>change details</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>withdrawal</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>response</th>
#       <td>    101</td>
#     </tr>
#     <tr>
#       <th>talk with manager</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>message</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td>    101</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">collect at branch</th>
#       <th>purchase</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <th>...</th>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th rowspan="30" valign="top">old</th>
#       <th rowspan="4" valign="top">sign documents</th>
#       <th>message</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th rowspan="13" valign="top">start</th>
#       <th>purchase</th>
#       <td>    101</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td>    301</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>inquiry</th>
#       <td>    401</td>
#     </tr>
#     <tr>
#       <th>change details</th>
#       <td>    201</td>
#     </tr>
#     <tr>
#       <th>withdrawal</th>
#       <td>    101</td>
#     </tr>
#     <tr>
#       <th>response</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>talk with manager</th>
#       <td>    101</td>
#     </tr>
#     <tr>
#       <th>message</th>
#       <td>    101</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th rowspan="13" valign="top">end</th>
#       <th>purchase</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>inquiry</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>change details</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>withdrawal</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>response</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>talk with manager</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>message</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td> 100000</td>
#     </tr>
#   </tbody>
# </table>
# <p>364 rows × 1 columns</p>
# </div>

# %%
# CALCULATE ACTION-ACTION CPT
# df_trans = df_trans[df_trans.to_action != 'end']
df_action_action_cpt = df_action_action_count_smothed.groupby(level=[0,1]).transform(lambda x: x/x.sum()).rename(columns={'count':'prob'})
df_action_action_cpt
# Out:
# <div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>prob</th>
#     </tr>
#     <tr>
#       <th>cluster</th>
#       <th>from_action</th>
#       <th>to_action</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="30" valign="top">young</th>
#       <th rowspan="13" valign="top">purchase</th>
#       <th>purchase</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>inquiry</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>change details</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>withdrawal</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>response</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>talk with manager</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>message</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td> 0.004695</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td> 0.943662</td>
#     </tr>
#     <tr>
#       <th rowspan="13" valign="top">request</th>
#       <th>purchase</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>inquiry</th>
#       <td> 0.586745</td>
#     </tr>
#     <tr>
#       <th>change details</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>withdrawal</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>response</th>
#       <td> 0.196881</td>
#     </tr>
#     <tr>
#       <th>talk with manager</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>message</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td> 0.001949</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td> 0.196881</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">collect at branch</th>
#       <th>purchase</th>
#       <td> 0.003195</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td> 0.003195</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td> 0.003195</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td> 0.003195</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <th>...</th>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th rowspan="30" valign="top">old</th>
#       <th rowspan="4" valign="top">sign documents</th>
#       <th>message</th>
#       <td> 0.076923</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td> 0.076923</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td> 0.076923</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td> 0.076923</td>
#     </tr>
#     <tr>
#       <th rowspan="13" valign="top">start</th>
#       <th>purchase</th>
#       <td> 0.076923</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td> 0.229246</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td> 0.000762</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td> 0.000762</td>
#     </tr>
#     <tr>
#       <th>inquiry</th>
#       <td> 0.305407</td>
#     </tr>
#     <tr>
#       <th>change details</th>
#       <td> 0.153085</td>
#     </tr>
#     <tr>
#       <th>withdrawal</th>
#       <td> 0.076923</td>
#     </tr>
#     <tr>
#       <th>response</th>
#       <td> 0.000762</td>
#     </tr>
#     <tr>
#       <th>talk with manager</th>
#       <td> 0.076923</td>
#     </tr>
#     <tr>
#       <th>message</th>
#       <td> 0.076923</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td> 0.000762</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td> 0.000762</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td> 0.000762</td>
#     </tr>
#     <tr>
#       <th rowspan="13" valign="top">end</th>
#       <th>purchase</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>request</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>collect at branch</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>proposal</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>inquiry</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>change details</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>withdrawal</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>response</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>talk with manager</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>message</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>notification</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>sign documents</th>
#       <td> 0.000010</td>
#     </tr>
#     <tr>
#       <th>end</th>
#       <td> 0.999880</td>
#     </tr>
#   </tbody>
# </table>
# <p>364 rows × 1 columns</p>
# </div>

# %% [markdown]
# ###CREATE CLUSTER-ACTION-CHANNEL CPT

# %%
df_action_channel_count = DataFrame(df.groupby(['cluster','action_eng','channel']).count().loc[:,('trans_id')])
df_action_channel_count = df_action_channel_count.reset_index()
df_action_channel_count = df_action_channel_count.rename(columns={'action_eng':'action','trans_id':'count'}, axis=1)
df_action_channel_count
# Out:
# <div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cluster</th>
#       <th>action</th>
#       <th>channel</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0 </th>
#       <td>   old</td>
#       <td>    change details</td>
#       <td>   f2f</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td>   old</td>
#       <td>    change details</td>
#       <td> phone</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td>   old</td>
#       <td> collect at branch</td>
#       <td>   f2f</td>
#       <td>  3</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td>   old</td>
#       <td>           inquiry</td>
#       <td>   f2f</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td>   old</td>
#       <td>           inquiry</td>
#       <td>   ivr</td>
#       <td>  2</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td>   old</td>
#       <td>           inquiry</td>
#       <td> phone</td>
#       <td>  4</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td>   old</td>
#       <td>           inquiry</td>
#       <td>   web</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td>   old</td>
#       <td>           message</td>
#       <td>  post</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td>   old</td>
#       <td>      notification</td>
#       <td>   f2f</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td>   old</td>
#       <td>          purchase</td>
#       <td>   f2f</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>   old</td>
#       <td>           request</td>
#       <td>   f2f</td>
#       <td>  2</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>   old</td>
#       <td>           request</td>
#       <td> phone</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>   old</td>
#       <td> talk with manager</td>
#       <td>   f2f</td>
#       <td>  2</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>   old</td>
#       <td>        withdrawal</td>
#       <td>   f2f</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td> young</td>
#       <td>    change details</td>
#       <td>   web</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td> young</td>
#       <td> collect at branch</td>
#       <td>   f2f</td>
#       <td>  3</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td> young</td>
#       <td>           inquiry</td>
#       <td> phone</td>
#       <td> 10</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td> young</td>
#       <td>           inquiry</td>
#       <td>   web</td>
#       <td>  2</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td> young</td>
#       <td>          proposal</td>
#       <td> phone</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td> young</td>
#       <td>          purchase</td>
#       <td> phone</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td> young</td>
#       <td>          purchase</td>
#       <td>   web</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td> young</td>
#       <td>           request</td>
#       <td> phone</td>
#       <td>  3</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td> young</td>
#       <td>           request</td>
#       <td>   web</td>
#       <td>  2</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td> young</td>
#       <td>          response</td>
#       <td> phone</td>
#       <td>  3</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td> young</td>
#       <td>    sign documents</td>
#       <td>   f2f</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td> young</td>
#       <td> talk with manager</td>
#       <td>   f2f</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td> young</td>
#       <td>        withdrawal</td>
#       <td>   ivr</td>
#       <td>  1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# CREATE ACTION-CHANNEL SMOOTHING TABLE
distinct_actions = df.action_eng.unique().tolist()+['end']
distinct_channels = df.channel.unique().tolist()
# +['start']
clusters = df_trans.cluster.unique()
lst_action_channel = []
for c in clusters:
    for f in distinct_actions:
        for t in distinct_channels:
            lst_action_channel.append((c,f,t,1))
        
df_action_channel_smoothing = DataFrame(lst_action_channel, columns=['cluster','action', 'channel', 'count'])
df_action_channel_smoothing
# Out:
# <div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cluster</th>
#       <th>action</th>
#       <th>channel</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0  </th>
#       <td> young</td>
#       <td>          purchase</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>1  </th>
#       <td> young</td>
#       <td>          purchase</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>2  </th>
#       <td> young</td>
#       <td>          purchase</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>3  </th>
#       <td> young</td>
#       <td>          purchase</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>4  </th>
#       <td> young</td>
#       <td>          purchase</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>5  </th>
#       <td> young</td>
#       <td>           request</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>6  </th>
#       <td> young</td>
#       <td>           request</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>7  </th>
#       <td> young</td>
#       <td>           request</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>8  </th>
#       <td> young</td>
#       <td>           request</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>9  </th>
#       <td> young</td>
#       <td>           request</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>10 </th>
#       <td> young</td>
#       <td> collect at branch</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>11 </th>
#       <td> young</td>
#       <td> collect at branch</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>12 </th>
#       <td> young</td>
#       <td> collect at branch</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>13 </th>
#       <td> young</td>
#       <td> collect at branch</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>14 </th>
#       <td> young</td>
#       <td> collect at branch</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>15 </th>
#       <td> young</td>
#       <td>          proposal</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>16 </th>
#       <td> young</td>
#       <td>          proposal</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>17 </th>
#       <td> young</td>
#       <td>          proposal</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>18 </th>
#       <td> young</td>
#       <td>          proposal</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>19 </th>
#       <td> young</td>
#       <td>          proposal</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>20 </th>
#       <td> young</td>
#       <td>           inquiry</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>21 </th>
#       <td> young</td>
#       <td>           inquiry</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>22 </th>
#       <td> young</td>
#       <td>           inquiry</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>23 </th>
#       <td> young</td>
#       <td>           inquiry</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>24 </th>
#       <td> young</td>
#       <td>           inquiry</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>25 </th>
#       <td> young</td>
#       <td>    change details</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>26 </th>
#       <td> young</td>
#       <td>    change details</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>27 </th>
#       <td> young</td>
#       <td>    change details</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>28 </th>
#       <td> young</td>
#       <td>    change details</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>29 </th>
#       <td> young</td>
#       <td>    change details</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>   old</td>
#       <td>          response</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>   old</td>
#       <td>          response</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>   old</td>
#       <td>          response</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>   old</td>
#       <td>          response</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>   old</td>
#       <td>          response</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>   old</td>
#       <td> talk with manager</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>   old</td>
#       <td> talk with manager</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>   old</td>
#       <td> talk with manager</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>   old</td>
#       <td> talk with manager</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>   old</td>
#       <td> talk with manager</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>110</th>
#       <td>   old</td>
#       <td>           message</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>   old</td>
#       <td>           message</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>   old</td>
#       <td>           message</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>113</th>
#       <td>   old</td>
#       <td>           message</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>114</th>
#       <td>   old</td>
#       <td>           message</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>115</th>
#       <td>   old</td>
#       <td>      notification</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>116</th>
#       <td>   old</td>
#       <td>      notification</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>117</th>
#       <td>   old</td>
#       <td>      notification</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>118</th>
#       <td>   old</td>
#       <td>      notification</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>   old</td>
#       <td>      notification</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>   old</td>
#       <td>    sign documents</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>121</th>
#       <td>   old</td>
#       <td>    sign documents</td>
#       <td>   f2f</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>122</th>
#       <td>   old</td>
#       <td>    sign documents</td>
#       <td> phone</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>123</th>
#       <td>   old</td>
#       <td>    sign documents</td>
#       <td>   ivr</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>124</th>
#       <td>   old</td>
#       <td>    sign documents</td>
#       <td>  post</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>125</th>
#       <td>   old</td>
#       <td>               end</td>
#       <td>   web</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>126</th>
#       <td>   old</td>
#       <td>               end</td>
#       <td>   f2

# %%
# CREATE ACTION-CHANNEL SMOOTHED
df_action_channel_count_smothed = pd.merge(df_action_channel_smoothing, df_action_channel_count.reset_index(), how='left', on=['cluster', 'action', 'channel'], suffixes=['','_y'])
df_action_channel_count_smothed.count_y.fillna(0, inplace=True)
df_action_channel_count_smothed['count'] = df_action_channel_count_smothed['count'] + df_action_channel_count_smothed['count_y']*100
df_action_channel_count_smothed.drop('count_y', inplace=True, axis=1)
# df_action_channel_count_smothed = df_action_channel_count_smothed[df_action_channel_count_smothed.channel != 'start']
df_action_channel_count_smothed.reset_index(inplace=True)
df_action_channel_count_smothed.drop(['index', 'level_0'], inplace=True, axis=1)
df_action_channel_count_smothed = df_action_channel_count_smothed.set_index(['cluster', 'action', 'channel'])
df_action_channel_count_smothed
# Out:
# <div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>cluster</th>
#       <th>action</th>
#       <th>channel</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="30" valign="top">young</th>
#       <th rowspan="5" valign="top">purchase</th>
#       <th>web</th>
#       <td>  101</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>  101</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">request</th>
#       <th>web</th>
#       <td>  201</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>  301</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">collect at branch</th>
#       <th>web</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>  301</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">proposal</th>
#       <th>web</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>  101</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">inquiry</th>
#       <th>web</th>
#       <td>  201</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 1001</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">change details</th>
#       <th>web</th>
#       <td>  101</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <th>...</th>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th rowspan="30" valign="top">old</th>
#       <th rowspan="5" valign="top">response</th>
#       <th>web</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">talk with manager</th>
#       <th>web</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>  201</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">message</th>
#       <th>web</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>  101</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">notification</th>
#       <th>web</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>  101</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">sign documents</th>
#       <th>web</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">end</th>
#       <th>web</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td>    1</td>
#     </tr>
#   </tbody>
# </table>
# <p>130 rows × 1 columns</p>
# </div>

# %%
df_action_chanel_cpt = df_action_channel_count_smothed.groupby(level=[0,1]).transform(lambda x: x/x.sum()).rename(columns={'count':'prob'})

df_action_chanel_cpt
# Out:
# <div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>prob</th>
#     </tr>
#     <tr>
#       <th>cluster</th>
#       <th>action</th>
#       <th>channel</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="30" valign="top">young</th>
#       <th rowspan="5" valign="top">purchase</th>
#       <th>web</th>
#       <td> 0.492683</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.004878</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.492683</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.004878</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.004878</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">request</th>
#       <th>web</th>
#       <td> 0.398020</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.001980</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.596040</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.001980</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.001980</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">collect at branch</th>
#       <th>web</th>
#       <td> 0.003279</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.986885</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.003279</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.003279</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.003279</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">proposal</th>
#       <th>web</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.961905</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">inquiry</th>
#       <th>web</th>
#       <td> 0.166805</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.000830</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.830705</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.000830</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.000830</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">change details</th>
#       <th>web</th>
#       <td> 0.961905</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <th>...</th>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th rowspan="30" valign="top">old</th>
#       <th rowspan="5" valign="top">response</th>
#       <th>web</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">talk with manager</th>
#       <th>web</th>
#       <td> 0.004878</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.980488</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.004878</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.004878</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.004878</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">message</th>
#       <th>web</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.961905</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">notification</th>
#       <th>web</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.961905</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.009524</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">sign documents</th>
#       <th>web</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">end</th>
#       <th>web</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>f2f</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>phone</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>ivr</th>
#       <td> 0.200000</td>
#     </tr>
#     <tr>
#       <th>post</th>
#       <td> 0.200000</td>
#     </tr>
#   </tbody>
# </table>
# <p>130 rows × 1 columns</p>
# </div>

# %% [markdown]
# ##create DBN Model - data generator - common model

# %%
import libpgm
from libpgm.graphskeleton import GraphSkeleton
from libpgm.dyndiscbayesiannetwork import DynDiscBayesianNetwork
from libpgm.orderedskeleton import OrderedSkeleton
import json

# %%
m = {}
m['V'] = ['Cluster','Channel','Action']
# m['E'] = [['Cluster', 'Action'],['past_Action','Action'],['Cluster','Channel'],['Action','Channel']]
m['E'] = [['Cluster', 'Action'],['Cluster','Channel'],['Action','Channel']]
m['initial_Vdata'] = {}
m['twotbn_Vdata'] = {}

# CONSTRUCT CLUSTER
c_vals = df.cluster.unique().tolist()
m['initial_Vdata']['Cluster'] = {'ord':0, 
                                 'numoutcomes':len(c_vals),
                                 'vals':c_vals,
                                 'parents':[],
                                 'children':['Action', 'Channel'],
                                 'cprob':[1/float(len(c_vals))]*len(c_vals)
                                }

def change_at_index(arr,i,v):
    arr[i]=v
    return arr

m['twotbn_Vdata']['Cluster'] = {'ord':0, 
                                 'numoutcomes':len(c_vals),
                                 'vals':c_vals,
                                 'parents':['past_Cluster'],
                                 'children':['Action', 'Channel'],
                                 'cprob':{'[\'%s\']' % v:change_at_index(len(c_vals)*[0],i,1) for i,v in enumerate(c_vals)}
                                }



# CONSTRUCT CLUSTER,ACTION => ACTION
zumb = df_action_action_cpt.reset_index()
a_vals = zumb.to_action.unique().tolist()
gr_cluster__action = df_action_action_cpt.xs('start', level='from_action').reset_index().groupby('cluster')
m['initial_Vdata']['Action'] = {'ord':1, 
                                'numoutcomes':len(a_vals),
                                'vals':a_vals,
                                'parents':['Cluster'],
                                'children':['Action','Channel'],
#                               {'[old]': [0.076, 0.229, ...], '[young]': [0.076, 0.229, ...]}
                                'cprob':{'[\'%s\']' % i:g.prob.tolist() for i,g in gr_cluster__action}
                                }

# zumb = df_action_action_cpt.reset_index()
gr_cluster_action__action = zumb.loc[zumb['from_action']!='start'].groupby(['cluster','from_action'])
m['twotbn_Vdata']['Action'] = {'ord':1, 
                                'numoutcomes':len(a_vals),
                                'vals':a_vals,
                                'parents':['Cluster','past_Action'],
                                'children':['Action','Channel'],
#                               {'['old', 'request']': [0.076, 0.229, ...], '['young','request']': [0.076, 0.229, ...]}
                                'cprob':{'%s' % list(i):g.prob.tolist() for i,g in gr_cluster_action__action}
                                }


# CONSTRUCT CLUSTER,ACTION => CHANNEL
ch_vals = df.channel.unique().tolist()
kuk = df_action_chanel_cpt.reset_index()
gr_cluster_action__channel = kuk.loc[kuk['action']!='start'].groupby(['cluster','action'])
m['initial_Vdata']['Channel'] = {'ord':2, 
                                'numoutcomes':len(ch_vals),
                                'vals':ch_vals,
                                'parents':['Cluster', 'Action'],
                                'children':[],
#                               {"['old', 'collect at branch']": [0.0032, 0.986 ..]"}
                                'cprob':{'%s' % list(i):g.prob.tolist() for i,g in gr_cluster_action__channel}
                                }

m['twotbn_Vdata']['Channel'] = {'ord':2, 
                                'numoutcomes':len(ch_vals),
                                'vals':ch_vals,
                                'parents':['Cluster', 'Action'],
                                'children':[],
#                               {"['old', 'collect at branch']": [0.0032, 0.986 ..]"}
                                'cprob':{'%s' % list(i):g.prob.tolist() for i,g in gr_cluster_action__channel}
                                }

# %%
d = DynDiscBayesianNetwork()
skel = GraphSkeleton()

skel.V = m["V"]
skel.E = m["E"]
skel.toporder()
d.V = skel.V
d.E = skel.E
d.initial_Vdata = m["initial_Vdata"]
d.twotbn_Vdata = m["twotbn_Vdata"]

# %%
data = []
for i in range(1):
    data.append(d.randomsample(10))

data
# Out:
# [[{'Action': 'inquiry', 'Channel': 'phone', 'Cluster': 'old'},
#   {'Action': 'inquiry', 'Channel': 'f2f', 'Cluster': 'old'},
#   {'Action': 'inquiry', 'Channel': 'phone', 'Cluster': 'old'},
#   {'Action': 'collect at branch', 'Channel': 'f2f', 'Cluster': 'old'},
#   {'Action': 'end', 'Channel': 'phone', 'Cluster': 'old'},
#   {'Action': 'end', 'Channel': 'phone', 'Cluster': 'old'},
#   {'Action': 'end', 'Channel': 'ivr', 'Cluster': 'old'},
#   {'Action': 'end', 'Channel': 'ivr', 'Cluster': 'old'},
#   {'Action': 'end', 'Channel': 'post', 'Cluster': 'old'},
#   {'Action': 'end', 'Channel': 'post', 'Cluster': 'old'}]]

# %%
with open('journeys_gen__action_channel_model.json', 'w') as fp:
    json.dump(m, fp)

# %% [markdown]
# ##create DBN Model - data generator - separate models for clusters

# %%
all_actions = df1.from_action.unique().tolist()
all_channels = df1.channel.unique().tolist()

#ACTIONS

start_action_cpt = df_action_action_cpt.xs('start', level='from_action').reset_index()
# start_action_cpt = start_action_cpt[~start_action_cpt['to_action'].isin(['end'])]
gr_cluster__action = start_action_cpt.groupby('cluster')
a_vals = start_action_cpt.to_action.unique().tolist()

zhuzhik = df_action_action_cpt.reset_index()
gr_action__action = zhuzhik[~zhuzhik['from_action'].isin(['start'])]
gr_action__action = gr_action__action[~gr_action__action['to_action'].isin(['start'])]
gr_action__action = gr_action__action.groupby(['cluster'])

#CHANNELS
ch_vals = df.channel.unique().tolist()
cherep = df_action_chanel_cpt.reset_index()
gr_cluster_action__channel = cherep[~cherep['action'].isin(['start'])].groupby('cluster')




def construct_model(cluster):
    m = {}
    m['V'] = ['action','channel']
    m['E'] = [['action','channel']]
    m['initial_Vdata'] = {}
    m['twotbn_Vdata'] = {}
    
    # CONSTRUCT ACTION => ACTION
    m['initial_Vdata']['action'] = {'ord':0, 
                                    'numoutcomes':len(a_vals),
                                    'vals':a_vals,
                                    'parents':[],
                                    'children':['channel'],
    #                               {'[old]': [0.076, 0.229, ...], '[young]': [0.076, 0.229, ...]}
                                    'cprob':gr_cluster__action.get_group(cluster).prob.tolist()
                                    }

    # zumb = df_action_action_cpt.reset_index()
    gr_cluster_action__action = zumb.loc[zumb['from_action']!='start'].groupby(['cluster','from_action'])
    m['twotbn_Vdata']['action'] = {'ord':0, 
                                    'numoutcomes':len(a_vals),
                                    'vals':a_vals,
                                    'parents':['past_action'],
                                    'children':['action','channel'],
    #                               {'request']': [0.076, 0.229, ...], '['request']': [0.076, 0.229, ...]}
                                    'cprob':{'%s' % [i]:g.prob.tolist() for i,g in gr_action__action.get_group(cluster).groupby('from_action')}
                                    }



    # CONSTRUCT ACTION => CHANNEL
    m['initial_Vdata']['channel'] = {'ord':1, 
                                    'numoutcomes':len(all_channels),
                                    'vals':all_channels,
                                    'parents':['action'],
                                    'children':[],
                                    'cprob':{'%s' % [i]:g.prob.tolist() for i,g in gr_cluster_action__channel.get_group(cluster).groupby('action')}
                                    }

    m['twotbn_Vdata']['channel'] = {'ord':1, 
                                    'numoutcomes':len(all_channels),
                                    'vals':all_channels,
                                    'parents':['action'],
    #                                 'children':[],
                                    'cprob':{'%s' % [i]:g.prob.tolist() for i,g in gr_cluster_action__channel.get_group(cluster).groupby('action')}
                                    }
    return m

# %%
models = {}
for c in ['young', 'old']:
    cm = construct_model(c)
    models[c] = cm

# %%
for c,m in models.iteritems():
    ld = DynDiscBayesianNetwork()
    lskel = GraphSkeleton()

    lskel.V = m["V"]
    lskel.E = m["E"]
    lskel.toporder()
    ld.V = lskel.V
    ld.E = lskel.E
    ld.initial_Vdata = m["initial_Vdata"]
    ld.twotbn_Vdata = m["twotbn_Vdata"]
    
    print ld.randomsample(10)
# Out:
# [{'action': 'inquiry', 'channel': 'f2f'}, {'action': 'collect at branch', 'channel': 'f2f'}, {'action': 'end', 'channel': 'phone'}, {'action': 'end', 'channel': 'web'}, {'action': 'end', 'channel': 'web'}, {'action': 'end', 'channel': 'f2f'}, {'action': 'end', 'channel': 'phone'}, {'action': 'end', 'channel': 'f2f'}, {'action': 'end', 'channel': 'f2f'}, {'action': 'end', 'channel': 'post'}]
# [{'action': 'withdrawal', 'channel': 'ivr'}, {'action': 'end', 'channel': 'f2f'}, {'action': 'end', 'channel': 'phone'}, {'action': 'end', 'channel': 'ivr'}, {'action': 'end', 'channel': 'f2f'}, {'action': 'end', 'channel': 'post'}, {'action': 'end', 'channel': 'web'}, {'action': 'end', 'channel': 'web'}, {'action': 'end', 'channel': 'phone'}, {'action': 'end', 'channel': 'phone'}]

# %%
for c,m in models.iteritems():
    with open('journeys__action_channel_model_%s.json' % c, 'w') as fp:
        json.dump(m, fp)

# %% [markdown]
# #create DBN Model - for learn

# %%
lm = {}
lm['V'] = ['action','channel']
lm['E'] = [['action','channel']]
lm['initial_Vdata'] = {}
lm['twotbn_Vdata'] = {}


all_actions = df1.from_action.unique().tolist()
all_channels = df1.channel.unique().tolist()


# CONSTRUCT ACTION => ACTION
lm['initial_Vdata']['action'] = {'ord':0, 
                                'numoutcomes':len(all_actions),
                                'vals':all_actions,
                                'parents':[],
                                'children':['channel'],
                                'cprob':[1/float(len(all_actions))]*len(all_actions)
                                }

lm['twotbn_Vdata']['action'] = {'ord':0, 
                                'numoutcomes':len(all_actions),
                                'vals':all_actions,
                                'parents':['past_action'],
                                'children':['action','channel'],
                                'cprob':{'%s' % [i]:[1/float(len(all_actions))]*len(all_actions) for i in all_actions}
                                }


# CONSTRUCT ACTION => CHANNEL
lm['initial_Vdata']['channel'] = {'ord':1, 
                                'numoutcomes':len(all_channels),
                                'vals':all_channels,
                                'parents':['action'],
                                'children':[],
                                'cprob':{'%s' % [i]:[1/float(len(all_channels))]*len(all_channels) for i in all_actions}
                                }

lm['twotbn_Vdata']['channel'] = {'ord':1, 
                                'numoutcomes':len(all_channels),
                                'vals':all_channels,
                                'parents':['action'],
#                                 'children':[],
                                'cprob':{'%s' % [i]:[1/float(len(all_channels))]*len(all_channels) for i in all_actions}
                                }

# %%
{'%s' % [i]:[1/float(len(all_actions))]*len(all_actions) for i in all_actions}
# Out:
# {"['change details']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['collect at branch']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['inquiry']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['message']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['notification']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['proposal']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['purchase']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['request']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['response']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['sign documents']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['talk with manager']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  "['withdrawal']": [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333]}

# %%
ld = DynDiscBayesianNetwork()
lskel = GraphSkeleton()

lskel.V = lm["V"]
lskel.E = lm["E"]
lskel.toporder()
ld.V = lskel.V
ld.E = lskel.E
ld.initial_Vdata = lm["initial_Vdata"]
ld.twotbn_Vdata = lm["twotbn_Vdata"]

# %%
data = []
for i in range(1):
    data.append(ld.randomsample(10))

data
# Out:
# [[{'action': 'proposal', 'channel': 'ivr'},
#   {'action': 'response', 'channel': 'phone'},
#   {'action': 'request', 'channel': 'ivr'},
#   {'action': 'withdrawal', 'channel': 'phone'},
#   {'action': 'collect at branch', 'channel': 'ivr'},
#   {'action': 'inquiry', 'channel': 'post'},
#   {'action': 'collect at branch', 'channel': 'phone'},
#   {'action': 'talk with manager', 'channel': 'phone'},
#   {'action': 'collect at branch', 'channel': 'phone'},
#   {'action': 'request', 'channel': 'post'}]]

# %%
with open('journeys__action_channel_model.json', 'w') as fp:
    json.dump(lm, fp)
